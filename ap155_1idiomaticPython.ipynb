# %% [markdown]
# # AP 155 Lab Assignment
# ---
# ## Exercise 1: Idiomatic Python
#
# _Instruction_:
# - Complete the Student Information.
# - Answer each problem as completely as you can and summarize your results clearly and concisely in the **Report** section.
# - Write your programs in the **Code** section and make sure they are functional, efficient, and documented since we will run your code to see if it works.
#
# ### Student Information
# _Full Name (Last Name, First Name)_: Grefal, Jesse Rudyll
#
# _Student No._: 20XX-XXXXX
#
# _Section_: THR-TX-3
#
# ### Grading Information (c/o Lab Instructor)
#
# | Criteria | Score | Subtotal |
# | --- | --- | --- |
# | Report figure | XX | 20 |
# | Report discussion | XX | 20|
# | Code replicability & readability | XX | 20 |
# | Code efficiency & vectorization | XX | 20 |
# | Code method appropriateness & justification | XX | 20 |
# | **TOTAL** | XXX | 100 |
#
# _Date and Time Scored (MM/DD/YYYY HH:MM AM/PM):_:_

# %% [markdown]
# ---
# ## Section 1: Report

# %% [markdown]
# ### Subsection 1
#
# <img src="figures/loan-7AIDE8PrvA0-unsplash.jpg" width="45%" align="center">  <img src="figures/loan-7AIDE8PrvA0-unsplash.jpg" width="45%" align="center">
#
#
# Insert caption here. The syntax in markdown for putting a figure is `<img src="relative_path/to/figure.png" width="75%">`. Describe the figure briefly and concisely, and make sure the figure has complete elements.
#
# ### Subsection 2
#
# EDIT ME. Insert your discussion here. Do not exceed 150 words for this paragraph.

# %% [markdown]
# ---
# ## Section 2: Code

# %% [markdown]
# ### Problem 1

# %% [markdown]
# Output: on top of different approaches, compare results with different b (log-space) and different number precision.

# %% [markdown]
# ![Problem 1](figures/prob2_6.png)

# %%
a = 1.0   # can be cast to specify dtype, e.g. `a = np.float16(1.0)`
c = 1.0
b = 1.0e8

x_minus = (-b - np.sqrt(b**2 - 4*a*c))/(2*a)
x_plus = (-b + np.sqrt(b**2 - 4*a*c))/(2*a)

print(x_plus, x_minus)
# Out:
# -7.450580596923828e-09 -100000000.0

# %% [markdown]
# Explain in 2-3 sentences why the "bad" and "good" formula of the roots give out the values they do (what makes "good" good)? What led to the difference between the obtained values?

# %% [markdown]
# ### Problem 2

# %% [markdown]
# ![Problem 1](figures/prob2_8.png)

# %% [markdown]
# Produce a figure that compares how $f(x)$ approaches a certain value as $x$ approaches zero, between directly computing $f(x)$ and by using a trigonometric identity to "avoid the cancellation".
#
# (Bonus: also compare with different hardware floating-point precisions: 16/32/64/128-bit)

# %% [markdown]
# ![Flow image](figures/ap155_0_bifurcationdiagram.png)
#
# This is the figure's caption. Save your Python-generated figure inside your current directory and use the syntax `![Alternative text](Path to your image from your current folder)`.
#
# Discuss your key results with a maximum of 150 words.
#
# ## Other comments
# - A self reflection can be placed here.
# - This portion is not graded.
#
# ---

# %% [markdown]
# ---
# ## Section 3: Background

# %% [markdown]
# ### Floating-point representation

# %% [markdown]
# Python uses 64-bit float by default for any number you type in with a decimal point. Different floating point precision can be used at a lower level, which we can go around by using Numpy dtypes.
#
# Useful links:
# - [(Goldberg, 1991) What every computer scientist should know about floating-point arithmetic](https://dl.acm.org/doi/10.1145/103162.103163)
# - [Wikipedia - Floating-point arithmetic](https://en.wikipedia.org/wiki/Floating-point_arithmetic)
# - [Data types - NumPy](https://numpy.org/doc/stable/user/basics.types.html)
# - [decimal — Decimal fixed-point and floating-point arithmetic](https://docs.python.org/3/library/decimal.html)
# - [fractions — Rational numbers](https://docs.python.org/3/library/fractions.html)

# %% [markdown]
# ![Flow image](figures/fpflow.png)
